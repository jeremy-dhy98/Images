# %%
from PIL import Image, ImageDraw, ImageFont
import IPython.display as ipd
import cairo
import math

# %%
# Create a blank canvas
width, height = 400, 400
image = Image.new("RGB", (width, height), "white")
draw = ImageDraw.Draw(image)

# Draw a circle
draw.ellipse((100, 100, 300, 300), fill="blue", outline="black", width=5)

# Add text
font = ImageFont.truetype("arial.ttf", size=30)  
text = "My Logo"

# Calculate text size using textbbox
text_bbox = draw.textbbox((0, 0), text, font=font)
text_width = text_bbox[2] - text_bbox[0]
text_height = text_bbox[3] - text_bbox[1]

# Calculate the center position
text_x = (width - text_width) / 2
text_y = (height - text_height) / 2
# text_x = (width - text_width) // 2
# text_y = (height - text_height) // 2
draw.text((text_x, text_y), text, fill="white", font=font)

# Save the image
image.save("logo.png")
ipd.Image("logo.png", width=350, height=350, embed=True)

# %% [markdown]
# LOGOS USING CAIRO

# %%
# Create a surface (the image)
width, height = 200, 100
surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, width, height)
context = cairo.Context(surface)

# Set background color
context.set_source_rgb(1, 1, 1)  # White
context.paint()

# Draw a circle
context.set_source_rgb(0, 0, 1)  # Blue
context.arc(width / 2, height / 2, 30, 0, 2 * 3.14159)
context.fill()

# Add text (requires a font to be installed on your system)
context.set_source_rgb(0, 0, 0)  # Black
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)      
context.set_font_size(20)
context.move_to(width / 2 - 40, height / 2 + 10)
context.show_text("My Logo")

# Save the image
surface.write_to_png("my_logo.png")
ipd.Image("my_logo.png")
# , width=350, height=350, embed=True

# %%
WIDTH, HEIGHT = 256, 256

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
# Normalize the canvas
context.scale(WIDTH, HEIGHT)

pat = cairo.LinearGradient(0.0, 0.0, 0.0, 1.0)
pat.add_color_stop_rgba(1, 0.7, 0, 0, 0.5)
pat.add_color_stop_rgba(0, 0.9, 0.7, 0.2, 1)

# Draw a rectangle(0, 0, 1, 1)-->x1, y1, x2, y2
context.rectangle(0, 0, 1, 1)
context.set_source(pat)
context.fill()

# Change current transformation matrix
context.translate(0.1, 0.1)

context.move_to(0, 0)
# Draw a circle
context.arc(0.2, 0.1, 0.1, -math.pi / 2, 0)
context.line_to(0.5, 0.1) # Line to (x, y)
context.curve_to(0.5, 0.2, 0.5, 0.4, 0.2, 0.8) # (x1, y1, x2, y2, x3, y3)
context.close_path()

# Set bg color
context.set_source_rgb(0.3, 0.2, 0.5)
context.set_line_width(0.02)
context.stroke()

surface.write_to_png("example_raphic.png")
ipd.Image("example_raphic.png")

# %%
# # Set up the surface and context
# WIDTH, HEIGHT = 400, 400
# surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
# context = cairo.Context(surface)

# # Draw something
# context.set_source_rgb(0.2, 0.3, 0.5)  # White background
# context.rectangle(0, 0, WIDTH, HEIGHT)
# context.fill()

# # Draw a rectangle
# x, y = 
# context.rectangle(x, y, width, height)
# context.set_source_rgb(0.1, 0.2, 0.5)  # Set color
# context.fill()

# # Draw a circle
# x, y =
# context.arc(x, y, radius, start_angle, end_angle)  # Angles in radians
# context.set_source_rgb(1, 0, 0)  # Red
# context.fill_preserve()  # Fill and keep the path for stroke
# context.set_source_rgb(0, 0, 0)  # Black outline
# context.stroke()

# # Draw a line
# x1, x2, y1, y2 = 
# context.move_to(x1, y1)
# context.line_to(x2, y2)
# context.set_line_width(5)
# context.set_source_rgb(0, 0.5, 0)
# context.stroke()

# # Draw txt
# context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
# context.set_font_size(40)
# context.move_to(x, y)
# context.set_source_rgb(0, 0, 0)  # Black
# context.show_text("My Logo")
#  #
# text = "My Logo"
# x_bearing, y_bearing, width, height, _, _ = context.text_extents(text)
# context.move_to((WIDTH - width) / 2, (HEIGHT + height) / 2)
# context.show_text(text)


# # Save the image
# surface.write_to_png("output.png")
# ipd.Image("output.png")

# # Gradients
# gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
# gradient.add_color_stop_rgb(0, 1, 0, 0)  # Red at start
# gradient.add_color_stop_rgb(1, 0, 0, 1)  # Blue at end
# context.set_source(gradient)
# context.rectangle(0, 0, WIDTH, HEIGHT)
# context.fill()

# gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
# gradient.add_color_stop_rgb(0, 0.8, 0.8, 0.8)  # Light gray
# gradient.add_color_stop_rgb(1, 0.1, 0.1, 0.1)  # Dark gray
# context.set_source(gradient)
# context.arc(WIDTH / 2, HEIGHT / 2, 150, 0, 2 * 3.14159)
# context.fill()

# # Cliping paths -->This ensures paths do not interfere
# context.arc(WIDTH / 2, HEIGHT / 2, 100, 0, 2 * 3.14159)
# context.clip()  # Restrict drawing to the circle
# context.rectangle(0, 0, WIDTH, HEIGHT)
# context.set_source_rgb(1, 0, 0)  # Red
# context.fill()

# OUTPUTS
# surface.write_to_png("logo.png")
# surface = cairo.SVGSurface("logo.svg", WIDTH, HEIGHT)
# surface = cairo.PDFSurface("logo.pdf", WIDTH, HEIGHT)

# %% [markdown]
# PROFESSIONAL LOGO

# %%
WIDTH, HEIGHT = 500, 500

# Create surface and context
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White
context.fill()

# Draw a circle
context.arc(WIDTH / 2, HEIGHT / 2, 150, 0, 2 * 3.14159)  # Centered circle
context.set_source_rgb(0.1, 0.6, 0.8)  # Blue
context.fill()

# Add a border to the circle
context.arc(WIDTH / 2, HEIGHT / 2, 150, 0, 2 * 3.14159)
context.set_source_rgb(0, 0, 0)  # Black
context.set_line_width(5)
context.stroke()

# Add text
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(40)
text = "My Logo"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2)
context.set_source_rgb(1, 1, 1)  # White text
context.show_text(text)

# Save the output
surface.write_to_png("logo.png")
ipd.Image("logo.png")

# %% [markdown]
# JEREMY LOGO

# %%
# Canvas size
WIDTH, HEIGHT = 500, 500

# Create the surface and context
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background color
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Draw the outer circle
circle_center_x = WIDTH / 2
circle_center_y = HEIGHT / 2
circle_radius = 200

context.arc(circle_center_x, circle_center_y, circle_radius, 0, 2 * math.pi)
context.set_source_rgb(0.1, 0.6, 0.8)  # Light blue
context.fill_preserve()  # Fill but keep path for stroke
context.set_source_rgb(0, 0, 0)  # Black outline
context.set_line_width(2)
context.stroke()

# Draw the star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)  # Starting point
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

draw_star(context, circle_center_x, circle_center_y, spikes=5, outer_radius=150, inner_radius=75)
context.set_source_rgb(1, 1, 0)  # Yellow fill
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Add text "Jeremy" inside the star
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(40)
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to(circle_center_x - text_width / 2, circle_center_y + text_height / 4)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Circle that touches the edges of the star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(3)  # Thin stroke
context.stroke()

# Add "DEV" at the bottom of the star
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to(circle_center_x - text_width / 2, circle_center_y + 80)
context.set_source_rgb(0.2, 0.2, 0.2)  # Dark gray text
context.show_text(dev_text)

# Save the logo
surface.write_to_png("jeremy_logo.png")
ipd.Image("jeremy_logo.png")

# %% [markdown]
# JEREMY LOGO PROFESSIONAL
# - Adjusted fonts and styles
# - Gradients applied
# - Applied Shadows

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)
context.fill()

# Radial Gradient Circle
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)
gradient.add_color_stop_rgb(1, 1, 0, 0)
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Text
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(40)
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
gradient = cairo.LinearGradient(0, 0, WIDTH, 0)
gradient.add_color_stop_rgb(0, 1, 1, 0)
gradient.add_color_stop_rgb(1, 1, 0, 1)
context.set_source(gradient)
context.show_text(text)

# DEV text
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save output
surface.write_to_png("enhanced_jeremy_logo.png")
ipd.Image("enhanced_jeremy_logo.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)
context.fill()

# Radial Gradient Circle
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)
gradient.add_color_stop_rgb(1, 1, 0, 0)
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Text: Jeremy in bold black
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Increase size for prominence
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Text: DEV
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(255, 255, 255)
context.show_text(dev_text)

# Save output
surface.write_to_png("jeremy_logo_black_text.png")
ipd.Image("jeremy_logo_black_text.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Circle that touches the edges of the star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Text: Jeremy in bold black
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Increase size for prominence
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Text: DEV
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save output
surface.write_to_png("jeremy_logo_with_circle.png")
ipd.Image("jeremy_logo_with_circle.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Circle that touches the edges of the star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Small stars between the edges of the big star
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    for i in range(spikes):
        # Calculate position for each small star
        angle = i * angle_step + angle_step / 2  # Halfway between big star tips
        x = cx + math.sin(angle) * (big_star_outer_radius + small_star_outer_radius) / 2
        y = cy - math.cos(angle) * (big_star_outer_radius + small_star_outer_radius) / 2

        # Draw the small star
        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow color for the small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

# Parameters for small stars
small_star_outer_radius = 30  # Outer radius of small stars
small_star_inner_radius = 15  # Inner radius of small stars

# Draw small stars
draw_small_stars(context, WIDTH / 2, HEIGHT / 2, 5, 150, small_star_outer_radius, small_star_inner_radius)

# Text: Jeremy in bold black
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Increase size for prominence
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Text: DEV
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save output
surface.write_to_png("jeremy_logo_with_small_stars.png")
ipd.Image("jeremy_logo_with_small_stars.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Draw the white circle touching the edges of the big star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Draw small stars between the edges of the big star and the white circle
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, white_circle_radius, padding, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    safe_radius = (big_star_outer_radius + white_circle_radius) / 2 - padding  # Ensure stars are within safe bounds

    for i in range(spikes):
        # Calculate position for each small star within the safe radius
        angle = i * angle_step + angle_step / 2  # Halfway between big star tips
        x = cx + math.sin(angle) * safe_radius
        y = cy - math.cos(angle) * safe_radius

        # Draw the small star
        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow color for the small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

# Parameters for small stars and padding
small_star_outer_radius = 20  # Smaller outer radius for small stars
small_star_inner_radius = 10  # Smaller inner radius for small stars
padding = 20  # Distance from big star and white circle

# Draw small stars ensuring they don't touch the white circle or big star
draw_small_stars(
    context, WIDTH / 2, HEIGHT / 2, 5, 
    150,  # Big star outer radius
    150,  # White circle radius
    padding, 
    small_star_outer_radius, small_star_inner_radius
)

# Add text: "Jeremy" in bold black
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Increase size for prominence
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Add text: "DEV" below "Jeremy"
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save output
surface.write_to_png("jeremy_logo_with_enhancements.png")
ipd.Image("jeremy_logo_with_enhancements.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Draw the white circle touching the edges of the big star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Draw a white square that touches the white circle's circumference
def draw_square(context, cx, cy, radius, color):
    side_length = 2 * radius / math.sqrt(2)  # Calculate side length
    top_left_x = cx - side_length / 2
    top_left_y = cy - side_length / 2

    # Draw the square
    context.rectangle(top_left_x, top_left_y, side_length, side_length)
    context.set_source_rgb(*color)  # Set square color (white)
    context.fill_preserve()
    context.set_line_width(1)
    context.stroke()

# Parameters for the square
square_color = (1, 1, 1)  # White color
draw_square(context, WIDTH / 2, HEIGHT / 2, outer_radius, square_color)

# Draw small stars between the edges of the big star and the white circle
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, white_circle_radius, padding, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    safe_radius = (big_star_outer_radius + white_circle_radius) / 2 - padding  # Ensure stars are within safe bounds

    for i in range(spikes):
        # Calculate position for each small star within the safe radius
        angle = i * angle_step + angle_step / 2  # Halfway between big star tips
        x = cx + math.sin(angle) * safe_radius
        y = cy - math.cos(angle) * safe_radius

        # Draw the small star
        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow color for the small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

# Parameters for small stars and padding
small_star_outer_radius = 20  # Smaller outer radius for small stars
small_star_inner_radius = 10  # Smaller inner radius for small stars
padding = 20  # Distance from big star and white circle

# Draw small stars ensuring they don't touch the white circle or big star
draw_small_stars(
    context, WIDTH / 2, HEIGHT / 2, 5, 
    150,  # Big star outer radius
    150,  # White circle radius
    padding, 
    small_star_outer_radius, small_star_inner_radius
)

# Add text: "Jeremy" in bold black
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Increase size for prominence
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Add text: "DEV" below "Jeremy"
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save output
surface.write_to_png("jeremy_logo_with_square.png")
ipd.Image("jeremy_logo_with_square.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Draw a white square that touches the white circle's circumference
def draw_outer_square(context, cx, cy, radius, outline_color, outline_width):
    side_length = 2 * radius  # The side length should be twice the circle's diameter
    top_left_x = cx - side_length / 2
    top_left_y = cy - side_length / 2

    # Set source color for the square outline
    context.set_source_rgb(*outline_color)
    context.set_line_width(outline_width)

    # Draw only the square's outline
    context.rectangle(top_left_x, top_left_y, side_length, side_length)
    context.stroke()

outer_radius = 150  # Match the circle's radius

# Parameters for square's outline
square_outline_color = (1, 1, 1)  # Pure white
square_outline_width = 2  # Thin stroke

# Draw the square outline
draw_outer_square(context, WIDTH / 2, HEIGHT / 2, outer_radius, square_outline_color, square_outline_width)

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Deep red at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

# Draw the star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Add text: "Jeremy" in bold black
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Add text: "DEV" below "Jeremy"
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save your output
surface.write_to_png("jeremy_logo_with_outlined_square.png")
ipd.Image("jeremy_logo_with_outlined_square.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Draw the white circle touching the edges of the big star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Draw a white square with only an outline that touches the white circle's circumference
def draw_outer_square(context, cx, cy, radius, outline_color, outline_width):
    side_length = 2 * radius / math.sqrt(2)  # Calculate side length
    top_left_x = cx - side_length / 2
    top_left_y = cy - side_length / 2

    context.set_source_rgb(*outline_color)
    context.set_line_width(outline_width)

    context.rectangle(top_left_x, top_left_y, side_length, side_length)
    context.stroke()

# Parameters for square
square_outline_color = (1, 1, 1)  # Pure white
square_outline_width = 2  # Thin stroke

draw_outer_square(context, WIDTH / 2, HEIGHT / 2, outer_radius, square_outline_color, square_outline_width)

# Draw small stars between the edges of the big star and the white circle
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, white_circle_radius, padding, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    safe_radius = (big_star_outer_radius + white_circle_radius) / 2 - padding  # Ensure stars are within bounds

    for i in range(spikes):
        angle = i * angle_step + angle_step / 2  # Halfway between big star tips
        x = cx + math.sin(angle) * safe_radius
        y = cy - math.cos(angle) * safe_radius

        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow for small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

# Parameters for small stars
small_star_outer_radius = 20  # Outer radius for small stars
small_star_inner_radius = 10  # Inner radius for small stars
padding = 20  # Space to keep stars clear of circle/star boundaries

# Draw small stars ensuring they don't touch the circle or big star
draw_small_stars(
    context, WIDTH / 2, HEIGHT / 2, 5, 
    150,  # Big star outer radius
    150,  # White circle radius
    padding, 
    small_star_outer_radius, small_star_inner_radius
)

# Add text "Jeremy" in bold black font
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Prominent text size
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Add text "DEV" in italic bold font
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save your output
surface.write_to_png("jeremy_logo_with_enhancements&.png")
ipd.Image("jeremy_logo_with_enhancements&.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    points = []

    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        points.append((x, y))
        context.line_to(x, y)

    context.close_path()

    return points

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)

spikes = 5
outer_radius = 150
inner_radius = 75

# Get the points of the star
star_points = draw_star(context, WIDTH / 2, HEIGHT / 2, spikes, outer_radius, inner_radius)
context.fill_preserve()

# Black outline for the star
context.set_source_rgb(0, 0, 0)
context.stroke()

# Draw white lines connecting all the edges of the star
context.set_source_rgb(1, 1, 1)  # White lines
context.set_line_width(5)

num_points = len(star_points)

for i in range(num_points):
    next_index = (i + 1) % num_points  # Wrap around to form a loop
    x1, y1 = star_points[i]
    x2, y2 = star_points[next_index]
    context.move_to(x1, y1)
    context.line_to(x2, y2)
    context.stroke()

# Draw the white circle touching the edges of the big star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Draw a white square with only an outline that touches the white circle's circumference
def draw_outer_square(context, cx, cy, radius, outline_color, outline_width):
    side_length = 2 * radius / math.sqrt(2)  # Calculate side length
    top_left_x = cx - side_length / 2
    top_left_y = cy - side_length / 2

    context.set_source_rgb(*outline_color)
    context.set_line_width(outline_width)

    context.rectangle(top_left_x, top_left_y, side_length, side_length)
    context.stroke()

square_outline_color = (1, 1, 1)  # Pure white
square_outline_width = 2  # Thin stroke
draw_outer_square(context, WIDTH / 2, HEIGHT / 2, outer_radius, square_outline_color, square_outline_width)

# Draw small stars between the edges of the big star and the white circle
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, white_circle_radius, padding, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    safe_radius = (big_star_outer_radius + white_circle_radius) / 2 - padding  # Ensure stars are within bounds

    for i in range(spikes):
        angle = i * angle_step + angle_step / 2
        x = cx + math.sin(angle) * safe_radius
        y = cy - math.cos(angle) * safe_radius

        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow for small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

small_star_outer_radius = 20
small_star_inner_radius = 10
padding = 20

draw_small_stars(
    context, WIDTH / 2, HEIGHT / 2, 5, 
    150,  # Big star outer radius
    150,  # White circle radius
    padding, 
    small_star_outer_radius, small_star_inner_radius
)

# Add text: "JEREMY ART AND DESIGNS" around the circle
def draw_circular_text(context, text, cx, cy, radius):
    num_chars = len(text)
    angle_step = 2 * math.pi / num_chars

    context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
    context.set_font_size(20)

    for i, char in enumerate(text):
        angle = i * angle_step - math.pi / 2  # Start from top
        x = cx + math.cos(angle) * radius - 10  # Slight adjustment for centering
        y = cy + math.sin(angle) * radius + 10

        context.move_to(x, y)
        context.set_source_rgb(255, 255, 255)  # Black text
        context.show_text(char)

draw_circular_text(context, "*JEREMY*ARTS*AND*DESIGNS*", WIDTH / 2, HEIGHT / 2, 160)

# Add text "Jeremy" in bold black font
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Prominent text size
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Add text "DEV" in italic bold font
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save your output
surface.write_to_png("jeremy_logo_with_circle_text_2.png")
ipd.Image("jeremy_logo_with_circle_text_2.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 500, 500
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 200)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 200, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        context.line_to(x, y)
    context.close_path()

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)
context.set_line_width(5)
draw_star(context, WIDTH / 2, HEIGHT / 2, 5, 150, 75)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)  # Black outline
context.stroke()

# Draw the white circle touching the edges of the big star
outer_radius = 150  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Draw a white square with only an outline that touches the white circle's circumference
def draw_outer_square(context, cx, cy, radius, outline_color, outline_width):
    side_length = 2 * radius / math.sqrt(2)  # Calculate side length
    top_left_x = cx - side_length / 2
    top_left_y = cy - side_length / 2

    context.set_source_rgb(*outline_color)
    context.set_line_width(outline_width)

    context.rectangle(top_left_x, top_left_y, side_length, side_length)
    context.stroke()

square_outline_color = (1, 1, 1)  # Pure white
square_outline_width = 2  # Thin stroke
draw_outer_square(context, WIDTH / 2, HEIGHT / 2, outer_radius, square_outline_color, square_outline_width)

# Draw small stars between the edges of the big star and the white circle
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, white_circle_radius, padding, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    safe_radius = (big_star_outer_radius + white_circle_radius) / 2 - padding  # Ensure stars are within bounds

    for i in range(spikes):
        angle = i * angle_step + angle_step / 2
        x = cx + math.sin(angle) * safe_radius
        y = cy - math.cos(angle) * safe_radius

        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow for small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

small_star_outer_radius = 20
small_star_inner_radius = 10
padding = 20

draw_small_stars(
    context, WIDTH / 2, HEIGHT / 2, 5, 
    150,  # Big star outer radius
    150,  # White circle radius
    padding, 
    small_star_outer_radius, small_star_inner_radius
)

# Add text: "JEREMY ART AND DESIGNS" around the circle
def draw_circular_text(context, text, cx, cy, radius):
    num_chars = len(text)
    angle_step = 2 * math.pi / num_chars

    context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
    context.set_font_size(25)

    for i, char in enumerate(text):
        angle = i * angle_step - math.pi / 2  # Start from top
        x = cx + math.cos(angle) * radius - 10  # Slight adjustment for centering
        y = cy + math.sin(angle) * radius + 10

        context.move_to(x, y)
        context.set_source_rgb(255, 255, 255)  # Black text
        context.show_text(char)

draw_circular_text(context, "* JEREMY * ARTS * AND * DESIGNS", WIDTH / 2, HEIGHT / 2, 160)

# Add text "Jeremy" in bold black font
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)  # Prominent text size
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 20)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text)

# Add text "DEV" in italic bold font
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(20)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 80)
context.set_source_rgb(0.2, 0.2, 0.2)
context.show_text(dev_text)

# Save your output
surface.write_to_png("jeremy_logo_with_circle_text.png")
ipd.Image("jeremy_logo_with_circle_text.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 1280, 720
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 300)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 300, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    points = []

    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        points.append((x, y))
        context.line_to(x, y)

    context.close_path()

    return points

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)

spikes = 5
outer_radius = 250
inner_radius = 125

# Get the points of the star
star_points = draw_star(context, WIDTH / 2, HEIGHT / 2, spikes, outer_radius, inner_radius)
context.fill_preserve()

# Black outline for the star
context.set_source_rgb(0, 0, 0)
context.stroke()

# Draw white lines connecting all the edges of the star
context.set_source_rgb(1, 1, 1)  # White lines
context.set_line_width(5)

num_points = len(star_points)

for i in range(num_points):
    next_index = (i + 1) % num_points  # Wrap around to form a loop
    x1, y1 = star_points[i]
    x2, y2 = star_points[next_index]
    context.move_to(x1, y1)
    context.line_to(x2, y2)
    context.stroke()

# Draw the white circle touching the edges of the big star
outer_radius = 250  # Match the star's outer radius
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Draw a white square with only an outline that touches the white circle's circumference
def draw_outer_square(context, cx, cy, radius, outline_color, outline_width):
    side_length = 2 * radius / math.sqrt(2)  # Calculate side length
    top_left_x = cx - side_length / 2
    top_left_y = cy - side_length / 2

    context.set_source_rgb(*outline_color)
    context.set_line_width(outline_width)

    context.rectangle(top_left_x, top_left_y, side_length, side_length)
    context.stroke()

square_outline_color = (1, 1, 1)  # Pure white
square_outline_width = 2  # Thin stroke
draw_outer_square(context, WIDTH / 2, HEIGHT / 2, outer_radius, square_outline_color, square_outline_width)

# Draw small stars between the edges of the big star and the white circle
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, white_circle_radius, padding, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    safe_radius = (big_star_outer_radius + white_circle_radius) / 2 - padding  # Ensure stars are within bounds

    for i in range(spikes):
        angle = i * angle_step + angle_step / 2
        x = cx + math.sin(angle) * safe_radius
        y = cy - math.cos(angle) * safe_radius

        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow for small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

small_star_outer_radius = 30
small_star_inner_radius = 15
padding = 20

draw_small_stars(
    context, WIDTH / 2, HEIGHT / 2, 5, 
    250,  # Big star outer radius
    250,  # White circle radius
    padding, 
    small_star_outer_radius, small_star_inner_radius
)

# Add text: "JEREMY ART AND DESIGNS" around the circle
def draw_circular_text(context, text, cx, cy, radius):
    num_chars = len(text)
    angle_step = 2 * math.pi / num_chars

    context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
    context.set_font_size(30)

    for i, char in enumerate(text):
        angle = i * angle_step - math.pi / 2  # Start from top
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius

        context.save()
        context.translate(x, y)
        context.rotate(angle + math.pi / 2)  # Align with circle
        context.move_to(0, 0)
        context.set_source_rgb(1, 1, 1)  # White text
        context.show_text(char)
        context.restore()

draw_circular_text(context, "*JEREMY*ARTS*AND*DESIGNS*", WIDTH / 2, HEIGHT / 2, 280)

# Add text "Jeremy" in bold, contrasting color
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(70)
text = "Jeremy"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 50)
context.set_source_rgb(0, 0, 0)  # Black
context.show_text(text)

# Add text "DEV" in italic bold font
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(30)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 150)
context.set_source_rgb(0.3, 0.3, 0.3)  # Gray text
context.show_text(dev_text)

# Save your output
surface.write_to_png("jeremy_logo_1280x720.png")
ipd.Image("jeremy_logo_1280x720.png")

# %%
# Canvas setup
WIDTH, HEIGHT = 1280, 720
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 300)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 300, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    points = []

    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        points.append((x, y))
        context.line_to(x, y)

    context.close_path()
    return points

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0)  # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0)    # Red
context.set_source(gradient)

spikes = 5
outer_radius = 200
inner_radius = 100

# Get the points of the star
star_points = draw_star(context, WIDTH / 2, HEIGHT / 2, spikes, outer_radius, inner_radius)
context.fill_preserve()

# Black outline for the star
context.set_source_rgb(0, 0, 0)
context.stroke()

# Draw white lines connecting all the edges of the star
context.set_source_rgb(1, 1, 1)  # White lines
context.set_line_width(2)
num_points = len(star_points)

for i in range(num_points):
    next_index = (i + 1) % num_points  # Wrap around to form a loop
    x1, y1 = star_points[i]
    x2, y2 = star_points[next_index]
    context.move_to(x1, y1)
    context.line_to(x2, y2)
    context.stroke()

# Draw the white circle touching the edges of the big star
context.arc(WIDTH / 2, HEIGHT / 2, outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)  # Thin stroke
context.stroke()

# Draw a new circle touching all the inner edges of the big star
inner_circle_radius = inner_radius
context.arc(WIDTH / 2, HEIGHT / 2, inner_circle_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)  # White outline
context.set_line_width(2)
context.stroke()

# Draw a white square with only an outline that touches the white circle's circumference
def draw_outer_square(context, cx, cy, radius, outline_color, outline_width):
    side_length = 2 * radius / math.sqrt(2)  # Calculate side length
    top_left_x = cx - side_length / 2
    top_left_y = cy - side_length / 2

    context.set_source_rgb(*outline_color)
    context.set_line_width(outline_width)
    context.rectangle(top_left_x, top_left_y, side_length, side_length)
    context.stroke()

square_outline_color = (1, 1, 1)  # Pure white
square_outline_width = 2  # Thin stroke
draw_outer_square(context, WIDTH / 2, HEIGHT / 2, outer_radius, square_outline_color, square_outline_width)

# Draw small stars between the edges of the big star and the white circle
def draw_small_stars(context, cx, cy, spikes, big_star_outer_radius, white_circle_radius, padding, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    safe_radius = (big_star_outer_radius + white_circle_radius) / 2 - padding  # Ensure stars are within bounds

    for i in range(spikes):
        angle = i * angle_step + angle_step / 2
        x = cx + math.sin(angle) * safe_radius
        y = cy - math.cos(angle) * safe_radius

        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow for small stars
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

small_star_outer_radius = 20
small_star_inner_radius = 10
padding = 20

draw_small_stars(
    context, WIDTH / 2, HEIGHT / 2, 5, 
    200,  # Big star outer radius
    200,  # White circle radius
    padding, 
    small_star_outer_radius, small_star_inner_radius
)

# Add text: "Jeremy" adjusted to fit at the center of the new inner circle
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)

text = "Jeremy"
max_text_width = inner_circle_radius * 2 - 20  # Allow padding within the circle
font_size = 70  # Start with a large font size

while True:
    context.set_font_size(font_size)
    x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text)
    if text_width <= max_text_width:
        break
    font_size -= 1  # Decrease font size iteratively

x_center = (WIDTH - text_width) / 2
y_center = (HEIGHT + text_height) / 2 - 10  # Adjust for better visual alignment
context.move_to(x_center, y_center)
context.set_source_rgb(0, 0, 0)  # Contrasting color
context.show_text(text)

def draw_circular_text(context, text, cx, cy, radius):
    num_chars = len(text)
    angle_step = 2 * math.pi / num_chars

    context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
    context.set_font_size(30)

    for i, char in enumerate(text):
        angle = i * angle_step - math.pi / 2  # Start from top
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius

        context.save()
        context.translate(x, y)
        context.rotate(angle + math.pi / 2)  # Align with circle
        context.move_to(0, 0)
        context.set_source_rgb(1, 1, 1)  # White text
        context.show_text(char)
        context.restore()

draw_circular_text(context, "*JEREMY*ARTS*AND*DESIGNS*", WIDTH / 2, HEIGHT / 2, 280)

# Add text "DEV" in italic bold font
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(30)
dev_text = "DEV"
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(dev_text)
context.move_to((WIDTH - text_width) / 2, HEIGHT / 2 + 150)
context.set_source_rgb(0.3, 0.3, 0.3)  # Gray text
context.show_text(dev_text)

# Save your output
surface.write_to_png("jeremy_logo_updated_2.png")
ipd.Image('jeremy_logo_updated_2.png')

# %% [markdown]
# ADD Texture, Shadows, Shaders

# %%
# Parameters
WIDTH, HEIGHT = 1280, 720
background_color = (0, 0, 0)  # White background
gradient_colors = [(0, 0.6, 0.8, 1), (1, 0, 0.2, 0.4)]  # Radial gradient colors
big_star_colors = [(1, 0.8, 0), (1, 0, 0)]  # Gradient for big star (yellow to red)
text_main = "Jeremy"
circular_text = "*JEREMY*ARTS*AND*DESIGNS*"
italic_text = "DEV"

# Create canvas
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background with texture
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(*background_color)
context.fill()

# Adding a subtle radial gradient texture
texture_gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 100, WIDTH / 2, HEIGHT / 2, 400)
texture_gradient.add_color_stop_rgba(0, 0.95, 0.95, 0.95, 0.5)  # Light gray center
texture_gradient.add_color_stop_rgba(1, 0.8, 0.8, 0.8, 0.2)  # Darker gray edges
context.set_source(texture_gradient)
context.arc(WIDTH / 2, HEIGHT / 2, 400, 0, 2 * math.pi)
context.fill()

# Radial Gradient Circle
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 300)
gradient.add_color_stop_rgb(0, *gradient_colors[0][:3])
gradient.add_color_stop_rgb(1, *gradient_colors[1][:3])
context.arc(WIDTH / 2, HEIGHT / 2, 300, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    points = []
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        points.append((x, y))
        context.line_to(x, y)
    context.close_path()
    return points

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, *big_star_colors[0][:3])
gradient.add_color_stop_rgb(1, *big_star_colors[1][:3])
context.set_source(gradient)

big_star_outer_radius = 200
big_star_inner_radius = 100
star_points = draw_star(context, WIDTH / 2, HEIGHT / 2, 5, big_star_outer_radius, big_star_inner_radius)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Draw white circle touching the edges of the big star
context.arc(WIDTH / 2, HEIGHT / 2, big_star_outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw inner circle touching the inner edges of the big star
context.arc(WIDTH / 2, HEIGHT / 2, big_star_inner_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw white square with an outline touching the white circle's circumference
side_length = 2 * big_star_outer_radius / math.sqrt(2)
top_left_x = WIDTH / 2 - side_length / 2
top_left_y = HEIGHT / 2 - side_length / 2
context.rectangle(top_left_x, top_left_y, side_length, side_length)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw small stars
def draw_small_stars(context, cx, cy, spikes, radius, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    for i in range(spikes):
        angle = i * angle_step + angle_step / 2
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius
        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

draw_small_stars(context, WIDTH / 2, HEIGHT / 2, 5, 250, 20, 10)

# Add main text
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
font_size = 55
context.set_font_size(font_size)
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text_main)
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 10)
context.set_source_rgb(0, 0, 0)
context.show_text(text_main)

# Circular text
def draw_circular_text(context, text, cx, cy, radius):
    angle_step = 2 * math.pi / len(text)
    for i, char in enumerate(text):
        angle = i * angle_step - math.pi / 2
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius
        context.save()
        context.translate(x, y)
        context.rotate(angle + math.pi / 2)
        context.move_to(0, 0)
        context.set_source_rgb(1, 1, 1)  # White
        context.show_text(char)
        context.restore()

draw_circular_text(context, circular_text, WIDTH / 2, HEIGHT / 2, 280)

# Add italic text
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(30)
italic_text_x = (WIDTH - context.text_extents(italic_text)[2]) / 2
italic_text_y = HEIGHT / 2 + 150
context.move_to(italic_text_x, italic_text_y)
context.set_source_rgb(1, 1, 1)
context.show_text(italic_text)

# Save output
surface.write_to_png("jeremy_logo_enhanced_2.png")
ipd.Image("jeremy_logo_enhanced_2.png")

# %% [markdown]
# FURTHER ENHANCEMENTS

# %%
# Parameters
WIDTH, HEIGHT = 1280, 720
background_color = (1, 1, 1)  # White background
gradient_colors = [(0, 0.6, 0.8, 1), (1, 0, 0.2, 0.4)]  # Radial gradient colors
big_star_colors = [(1, 0.8, 0), (1, 0, 0)]  # Gradient for big star (yellow to red)
text_main = "Jeremy"
circular_text = "*JEREMY * ARTS * AND DESIGNS*"
italic_text = "DEV"

# Create canvas
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(*background_color)
context.fill()

# Radial Gradient Circle
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 300)
gradient.add_color_stop_rgb(0, *gradient_colors[0][:3])
gradient.add_color_stop_rgb(1, *gradient_colors[1][:3])
context.arc(WIDTH / 2, HEIGHT / 2, 300, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    points = []
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        points.append((x, y))
        context.line_to(x, y)
    context.close_path()
    return points

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, *big_star_colors[0][:3])
gradient.add_color_stop_rgb(1, *big_star_colors[1][:3])
context.set_source(gradient)

big_star_outer_radius = 200
big_star_inner_radius = 100
star_points = draw_star(context, WIDTH / 2, HEIGHT / 2, 5, big_star_outer_radius, big_star_inner_radius)
context.fill_preserve()
context.set_source_rgb(1, 1, 1)
context.stroke()

# Draw white circle touching the edges of the big star
context.arc(WIDTH / 2, HEIGHT / 2, big_star_outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw inner circle touching the inner edges of the big star
context.arc(WIDTH / 2, HEIGHT / 2, big_star_inner_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw white square with an outline touching the white circle's circumference
side_length = 2 * big_star_outer_radius / math.sqrt(2)
top_left_x = WIDTH / 2 - side_length / 2
top_left_y = HEIGHT / 2 - side_length / 2
context.rectangle(top_left_x, top_left_y, side_length, side_length)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw small stars around the circle
def draw_small_stars(context, cx, cy, spikes, radius, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    for i in range(spikes):
        angle = i * angle_step + angle_step / 2
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius
        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

draw_small_stars(context, WIDTH / 2, HEIGHT / 2, 5, 250, 20, 10)

# Draw an heptagon
def draw_hexagon(context, cx, cy, radius):
    angle_step = 2 * math.pi / 6 # 6 sides for a hexagon
    points = []
    for i in range(6):
        angle = i * angle_step
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius
        points.append((x, y))
    context.move_to(*points[0])
    for point in points[1:]:
        context.line_to(*point)
    context.close_path()
    context.stroke()

# Draw the Heptagon inside the innermost circle
hexagon_radius = big_star_inner_radius - 10  # Slightly smaller to fit inside the circle
context.set_source_rgb(1, 1, 1)  # Black color for heptagon stroke
draw_hexagon(context, WIDTH / 2, HEIGHT / 2, hexagon_radius)

# Draw an heart
def draw_heart(context, cx, cy, size):
    context.new_path()
    context.move_to(cx, cy + size * 0.25)
    context.curve_to(cx - size * 0.5, cy - size * 0.5, cx - size, cy + size * 0.5, cx, cy + size * 1.25)
    context.curve_to(cx + size, cy + size * 0.5, cx + size * 0.5, cy - size * 0.5, cx, cy + size * 0.25)
    context.close_path()
    context.fill_preserve()
    context.set_source_rgb(1, 0, 0)  # Red heart
    context.stroke()
    
# Draw the Heart at the center of the Heptagon
heart_size = 40  # Size of the heart in relation to the inner circle
context.set_source_rgb(1, 0, 0)  # Red heart color
draw_heart(context, WIDTH / 2, HEIGHT / 2, heart_size)

# Overlay the "Jeremy" text on top of the Heptagon
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)

# Set initial font size
font_size = 60
context.set_font_size(font_size)

# Measure text dimensions
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text_main)

# Calculate the maximum text width allowed based on the hexagon's size
hexagon_diameter = hexagon_radius * 2
while text_width > hexagon_diameter * 0.9:  # Ensure the text fits within the hexagon (with a 10% margin)
    font_size -= 1
    context.set_font_size(font_size)
    x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text_main)

# Center the text within the heptagon
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 10)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text_main)

# Add italic text
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)
italic_text_x = (WIDTH - context.text_extents(italic_text)[2]) / 2
italic_text_y = HEIGHT / 2 + 150
context.move_to(italic_text_x, italic_text_y)
context.set_source_rgb(1, 1, 1)
context.show_text(italic_text)

def draw_circular_text(context, text, cx, cy, radius):
    num_chars = len(text)
    angle_step = 2 * math.pi / num_chars

    context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
    context.set_font_size(33)

    for i, char in enumerate(text):
        angle = i * angle_step - math.pi / 2  # Start from top
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius

        context.save()
        context.translate(x, y)
        context.rotate(angle + math.pi / 2)  # Align with circle
        context.move_to(0, 0)
        context.set_source_rgb(1, 1, 1)  # White text
        context.show_text(char)
        context.restore()

draw_circular_text(context, "*JEREMY*ARTS*AND*DESIGNS*", WIDTH / 2, HEIGHT / 2, 280)
      

# Save output
surface.write_to_png("jeremy_logo_enhanced_2_aligned.png")
ipd.Image("jeremy_logo_enhanced_2_aligned.png")

# %% [markdown]
# REVERT TO ORIGINAL GRADIENT

# %%
# Parameters
WIDTH, HEIGHT = 1280, 720
surface = cairo.ImageSurface(cairo.Format.ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
text_main = "Jeremy"
circular_text = "*JEREMY * ARTS * AND DESIGNS*"
italic_text = "DEV"

# Background
context.rectangle(0, 0, WIDTH, HEIGHT)
context.set_source_rgb(1, 1, 1)  # White background
context.fill()

# Radial Gradient Circle (Outer Background Circle)
gradient = cairo.RadialGradient(WIDTH / 2, HEIGHT / 2, 50, WIDTH / 2, HEIGHT / 2, 300)
gradient.add_color_stop_rgb(0, 0.6, 0.8, 1)  # Light blue at center
gradient.add_color_stop_rgb(1, 0, 0.2, 0.4)  # Dark blue at edges
context.arc(WIDTH / 2, HEIGHT / 2, 300, 0, 2 * math.pi)
context.set_source(gradient)
context.fill_preserve()
context.set_source_rgb(0, 0, 0)
context.stroke()

# Function to draw a star
def draw_star(context, cx, cy, spikes, outer_radius, inner_radius):
    angle = math.pi / spikes
    points = []
    context.move_to(cx, cy - outer_radius)
    for i in range(2 * spikes + 1):
        radius = outer_radius if i % 2 == 0 else inner_radius
        x = cx + math.sin(i * angle) * radius
        y = cy - math.cos(i * angle) * radius
        points.append((x, y))
        context.line_to(x, y)
    context.close_path()
    return points

# Draw the big star
gradient = cairo.LinearGradient(0, 0, WIDTH, HEIGHT)
gradient.add_color_stop_rgb(0, 1, 0.8, 0) # Yellow
gradient.add_color_stop_rgb(1, 1, 0, 0) # Red
context.set_source(gradient)

big_star_outer_radius = 200
big_star_inner_radius = 100
star_points = draw_star(context, WIDTH / 2, HEIGHT / 2, 5, big_star_outer_radius, big_star_inner_radius)
context.fill_preserve()
context.set_source_rgb(1, 1, 1)
context.stroke()

# Draw white circle touching the edges of the big star
context.arc(WIDTH / 2, HEIGHT / 2, big_star_outer_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw inner circle touching the inner edges of the big star
context.arc(WIDTH / 2, HEIGHT / 2, big_star_inner_radius, 0, 2 * math.pi)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw white square with an outline touching the white circle's circumference
side_length = 2 * big_star_outer_radius / math.sqrt(2)
top_left_x = WIDTH / 2 - side_length / 2
top_left_y = HEIGHT / 2 - side_length / 2
context.rectangle(top_left_x, top_left_y, side_length, side_length)
context.set_source_rgb(1, 1, 1)
context.set_line_width(2)
context.stroke()

# Draw small stars around the circle
def draw_small_stars(context, cx, cy, spikes, radius, small_star_outer_radius, small_star_inner_radius):
    angle_step = 2 * math.pi / spikes
    for i in range(spikes):
        angle = i * angle_step + angle_step / 2
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius
        draw_star(context, x, y, 5, small_star_outer_radius, small_star_inner_radius)
        context.set_source_rgb(1, 1, 0)  # Yellow
        context.fill_preserve()
        context.set_source_rgb(0, 0, 0)  # Black outline
        context.stroke()

draw_small_stars(context, WIDTH / 2, HEIGHT / 2, 5, 250, 20, 10)

# Draw an heptagon
def draw_hexagon(context, cx, cy, radius):
    angle_step = 2 * math.pi / 6 # 6 sides for a hexagon
    points = []
    for i in range(6):
        angle = i * angle_step
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius
        points.append((x, y))
    context.move_to(*points[0])
    for point in points[1:]:
        context.line_to(*point)
    context.close_path()
    context.stroke()

# Draw the Heptagon inside the innermost circle
hexagon_radius = big_star_inner_radius - 10  # Slightly smaller to fit inside the circle
context.set_source_rgb(1, 1, 1)  # Black color for heptagon stroke
draw_hexagon(context, WIDTH / 2, HEIGHT / 2, hexagon_radius)

# Draw an heart
def draw_heart(context, cx, cy, size):
    context.new_path()
    context.move_to(cx, cy + size * 0.25)
    context.curve_to(cx - size * 0.5, cy - size * 0.5, cx - size, cy + size * 0.5, cx, cy + size * 1.25)
    context.curve_to(cx + size, cy + size * 0.5, cx + size * 0.5, cy - size * 0.5, cx, cy + size * 0.25)
    context.close_path()
    context.fill_preserve()
    context.set_source_rgb(1, 0, 0)  # Red heart
    context.stroke()
    
# Draw the Heart at the center of the Heptagon
heart_size = 40  # Size of the heart in relation to the inner circle
context.set_source_rgb(1, 0, 0)  # Red heart color
draw_heart(context, WIDTH / 2, HEIGHT / 2, heart_size)

# Overlay the "Jeremy" text on top of the Heptagon
context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)

# Set initial font size
font_size = 60
context.set_font_size(font_size)

# Measure text dimensions
x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text_main)

# Calculate the maximum text width allowed based on the hexagon's size
hexagon_diameter = hexagon_radius * 2
while text_width > hexagon_diameter * 0.9:  # Ensure the text fits within the hexagon (with a 10% margin)
    font_size -= 1
    context.set_font_size(font_size)
    x_bearing, y_bearing, text_width, text_height, _, _ = context.text_extents(text_main)

# Center the text within the heptagon
context.move_to((WIDTH - text_width) / 2, (HEIGHT + text_height) / 2 - 10)
context.set_source_rgb(0, 0, 0)  # Black text
context.show_text(text_main)

# Add italic text
context.select_font_face("Arial", cairo.FONT_SLANT_ITALIC, cairo.FONT_WEIGHT_BOLD)
context.set_font_size(50)
italic_text_x = (WIDTH - context.text_extents(italic_text)[2]) / 2
italic_text_y = HEIGHT / 2 + 150
context.move_to(italic_text_x, italic_text_y)
context.set_source_rgb(0, 0, 0)
context.show_text(italic_text)

# Circular text function (updated to render white text and moved inward)
def draw_circular_text(context, text, cx, cy, radius):
    num_chars = len(text)
    if num_chars == 0:
        return
    angle_step = 2 * math.pi / num_chars

    # Increase base font size for better visibility
    base_font_size = 36
    context.select_font_face("Arial", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_BOLD)
    context.set_font_size(base_font_size)

    # We'll fill white and avoid a dark stroke to keep characters pure white
    for i, char in enumerate(text):
        angle = i * angle_step - math.pi / 2  # Start from top
        x = cx + math.cos(angle) * radius
        y = cy + math.sin(angle) * radius

        context.save()
        context.translate(x, y)
        context.rotate(angle + math.pi / 2)  # Align with circle
        # Create text path for character
        context.move_to(0, 0)
        context.text_path(char)
        # Fill the text (white)
        context.set_source_rgb(1, 1, 1)
        context.fill()
        context.restore()

# Move circular text slightly inward so it's fully inside the outer gradient circle
circular_text_radius = 270  # previously 280; moved inward toward center
draw_circular_text(context, circular_text, WIDTH / 2, HEIGHT / 2, circular_text_radius)
    
# Save output
surface.write_to_png("jeremy_logo_enhanced_2_original.png")
ipd.Image("jeremy_logo_enhanced_2_original.png")
